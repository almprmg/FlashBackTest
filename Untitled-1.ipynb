# %%
import pandas as pd
from BackTest_bisc import BackTest
from Stratigy import Stratigy

timeframe = "1h"
timeflow = "5m"
symbol = "AGLDUSDT"
data_low = pd.read_csv(f'C:/Users\dell/Desktop/module Python for Analysis Tradr/data/{timeflow}/{symbol}.csv',index_col=0)
df1= pd.read_csv(r'C:\Users\dell\Desktop\module Python for Analysis Tradr\Backtest_orders\data.csv',index_col=0)
data_low.Date = pd.to_datetime(data_low.Date,unit='ms')
data_low.index = data_low.set_index(data_low.Date)
df1.Date = pd.to_datetime(df1.Date,unit='ms')
df1.index = df1.set_index(df1.Date)
class myClass(Stratigy):
    def init(self) -> None:
       super().init()
       self.highest_bot = df1.highest_bot
       self.highest_top = df1.highest_top

    def next(self) -> None:
        super().next()
        signal =  self.Data.loc[self.Data.Signal == 1].index[0]
        if self.Data.Signal[signal] == 1 :
            self.limet = self.highest_top[signal]
            highest_bot =self.highest_bot[signal]
            self.sl = highest_bot- ((self.limet - highest_bot) *3) 
            self.tp =  highest_bot + ((self.limet - highest_bot) *5) 
            
            self.buy(limet=self.limet ,tp=self.tp,sl= self.sl )
        elif signal.values[0] == 2:
            self.Data = self.Data.loc[self.Data.index > signal.index[0] ]

# %%
bt =BackTest(df1,data_low,myClass)      
bt.run()
# Out:
# index 0 is out of bounds for axis 0 with size 0

# %%
bt.result
# Out:
#              DateStart  Enter     tp     ls  Targit             EndDate
# 0  2022-09-02 17:00:00  0.347  0.363  0.331     1.0 2022-09-03 03:20:00
# 1  2022-09-10 12:00:00  0.418  0.430  0.406     1.0 2022-09-11 15:05:00
# 2  2022-09-11 20:00:00  0.418  0.430  0.406     0.0 2022-09-12 16:05:00
# 3  2022-09-16 08:00:00  0.347  0.363  0.331     0.0 2022-09-18 21:00:00
# 4  2022-09-21 13:00:00  0.320  0.328  0.312     0.0 2022-09-21 15:05:00
# 5  2022-09-21 18:00:00  0.320  0.328  0.312     0.0 2022-09-21 18:00:00
# 6  2022-09-26 05:00:00  0.320  0.328  0.312     1.0 2022-09-26 05:00:00
# 7  2022-09-26 06:00:00  0.320  0.328  0.312     1.0 2022-09-26 23:50:00
# 8  2022-09-27 16:00:00  0.323  0.335  0.311     0.0 2022-09-28 01:45:00
# 9  2022-10-01 06:00:00  0.322  0.330  0.314     1.0 2022-10-01 07:55:00
# 10 2022-10-04 08:00:00  0.322  0.330  0.314     1.0 2022-10-04 13:15:00
# 11 2022-10-05 08:00:00  0.323  0.331  0.315     1.0 2022-10-05 12:45:00
# 12 2022-10-05 14:00:00  0.323  0.331  0.315     1.0 2022-10-05 16:10:00
# 13 2022-10-07 00:00:00  0.323  0.331  0.315     1.0 2022-10-07 00:00:00
# 14 2022-10-07 09:00:00  0.323  0.331  0.315     1.0 2022-10-07 09:00:00
# 15 2022-10-08 13:00:00  0.323  0.331  0.315     1.0 2022-10-09 00:05:00
# 16 2022-10-09 02:00:00  0.322  0.330  0.314     0.0 2022-10-10 08:25:00
# 17 2022-10-11 00:00:00  0.312  0.324  0.300     1.0 2022-10-11 16:05:00
# 18 2022-10-11 18:00:00  0.312  0.324  0.300     0.0 2022-10-13 07:30:00
# 19 2022-10-13 18:00:00  0.312  0.324  0.300     1.0 2022-10-15 14:35:00
# 20 2022-10-16 18:00:00  0.312  0.320  0.304     1.0 2022-10-16 18:00:00
# 21 2022-10-18 15:00:00  0.312  0.320  0.304     0.0 2022-10-19 23:30:00
# 22 2022-10-21 09:00:00  0.298  0.334  0.262     1.0 2022-10-29 07:10:00
# 23 2022-10-29 14:00:00  0.312  0.332  0.292     1.0 2022-10-29 14:00:00
# 24 2022-10-29 15:00:00  0.312  0.332  0.292     1.0 2022-10-29 15:00:00
# 25 2022-10-29 23:00:00  0.312  0.332  0.292     1.0 2022-10-29 23:00:00
# 26 2022-10-30 01:00:00  0.312  0.332  0.292     1.0 2022-10-30 01:00:00
# 27 2022-11-02 07:00:00  0.312  0.332  0.292     1.0 2022-11-02 07:00:00
# 28 2022-11-08 18:00:00  0.312  0.332  0.292     0.0 2022-11-08 19:25:00
# 29 2022-11-13 20:00:00  0.224  0.260  0.188     0.0 2022-11-08 19:25:00

# %%
import numpy as np
import plotly.graph_objects as go
data= pd.read_csv(r'C:\Users\dell\Desktop\module Python for Analysis Tradr\Backtest_orders\data.csv',index_col=0)
chart_linex = []
chart_liney= [ ]
for indexass,blo in bt.result.iterrows():

    chart_linex.append(blo.DateStart)
    chart_linex.append(blo.EndDate)
    chart_liney.append(blo.Enter)
    chart_liney.append(blo.tp if blo.Targit else blo.sl )
fig = go.Figure( data=[go.Candlestick(x=pd.to_datetime(data.Date,unit='ms'),
        open=data['Open'],
        high=data['High'],
        low=data['Low'],
        close=data['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
for i in range(2,len(chart_linex),2):

        fig.add_trace(go.Scatter(x=chart_linex[i-2:i], y=chart_liney[i-2:i], mode='lines', line=dict(color='black'))) 
        fig.add_trace(go.Scatter(x=chart_linex[i-2:i], y=chart_liney[i-2:i], mode='markers', marker=dict(color=['green', 'red'])))





               
        
       
       
      






fig.show()
